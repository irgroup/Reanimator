# %%
import sys
sys.path.append('/workspace/src/')

# %%
#get text chunks to index
from dotenv import dotenv_values, load_dotenv
from sqlalchemy import create_engine
from sqlalchemy.orm import Session

from typing import List

from langchain_core.output_parsers import BaseOutputParser
from langchain_core.prompts import PromptTemplate
from pydantic import BaseModel, Field

import pickle
from tqdm import tqdm
import os
import pandas as pd
import json

import langchain_core.documents
from langchain_community.retrievers import BM25Retriever
from database.model import Base, Document, Table
from database.chunk_model import Chunk_Base, Chunk

from langchain_openai import ChatOpenAI

from preprocessing.utils import create_vectorstore, load_vectorstore, remove_enumeration
import nltk
from nltk.tokenize import word_tokenize

from langchain_community.retrievers import (
    ElasticSearchBM25Retriever,
)

nltk.download("punkt_tab")
db_vals = dotenv_values("/workspace/src/.env")
load_dotenv()
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
topics = pickle.load(open("/workspace/src/data/topics.pkl", "rb"))

# %%
# Output parser will split the LLM result into a list of queries
class LineListOutputParser(BaseOutputParser[List[str]]):
    """Output parser for a list of lines."""

    def parse(self, text: str) -> List[str]:
        lines = text.strip().split("\n")
        return list(filter(None, lines))  # Remove empty lines


output_parser = LineListOutputParser()

QUERY_PROMPT = PromptTemplate(
    input_variables=["question"],
    template="""You are an AI assistant specialized in retrieving scientific information. 
Your task is to generate five distinct rephrasings of the user question so they can be 
effectively used with both sparse (e.g., BM25) and dense (e.g., cosine similarity) retrieval methods. 
Make sure each rephrasing captures different potential keywords, synonyms, or contexts 
specific to scientific research. Provide the five versions separated by newlines.

Original question: {question}"""
)

llm = ChatOpenAI(temperature=0, model="gpt-4o-2024-11-20")

llm_chain = QUERY_PROMPT | llm | output_parser

# %%
#generate query variations
query_variations = {}
for query_id, query_info in tqdm(topics.items()):

    query_text = query_info["title"] + " " + query_info["description"]
    res = llm_chain.invoke(query_text)
    res = remove_enumeration(res)
    query_variations[query_id].append(query_text)
    query_variations[query_id] = res
    


#save query variations as json

with open("/workspace/src/data/query_variations.json", "w") as f:
    json.dump(query_variations, f)
# Out:
# 100%|██████████| 50/50 [02:14<00:00,  2.68s/it]

# %%
query_variations
# Out:
# {'1': ['What is the source or origin of the coronavirus responsible for COVID-19?',
#   'How did the COVID-19 pandemic begin, and what is the origin of the SARS-CoV-2 virus?',
#   'Where did the coronavirus that causes COVID-19 originate, and what are its origins?',
#   'What is the evolutionary or biological origin of the virus SARS-CoV-2 linked to COVID-19?',
#   'Can you explain the origins and initial emergence of the coronavirus behind COVID-19?'],
#  '2': ['How does the behavior of the coronavirus vary with different weather conditions?',
#   'What is the impact of seasonal weather changes on the transmission and activity of the coronavirus?',
#   'In what ways do temperature and humidity influence the spread of the coronavirus?',
#   'How are coronavirus infection rates affected by fluctuations in climate and weather patterns?',
#   'What role do environmental factors like weather play in the adaptability and spread of the coronavirus?'],
#  '3': ['Do individuals infected with SARS-CoV-2 develop immunity to the coronavirus, and is there potential for cross-protection against other coronaviruses?',
#   'Can SARS-CoV-2 infection lead to immunity, and does it provide cross-reactive protection against related viruses?',
#   'Is immunity established in people after SARS-CoV-2 infection, and could cross-protection occur with other coronaviruses?',
#   'Does infection with the SARS-CoV-2 virus result in immune protection, and is cross-immunity with other coronaviruses feasible?',
#   'After being infected with SARS-CoV-2, do individuals gain immunity, and is there evidence for cross-protective immunity against other coronavirus strains?'],
#  '4': ['What are the primary mechanisms by which COVID-19 leads to death in infected individuals?',
#   'How does the coronavirus cause fatal outcomes, and what are the physiological processes involved?',
#   'What are the key factors and complications that result in mortality from SARS-CoV-2 infection?',
#   'What are the biological and medical reasons behind deaths caused by COVID-19?',
#   'How does severe COVID-19 infection progress to life-threatening conditions and result in death?'],
#  '5': ['What therapeutic drugs have shown efficacy against SARS-CoV or SARS-CoV-2 in preclinical animal models of COVID-19?',
#   'Which pharmacological agents have demonstrated activity against SARS-CoV or SARS-CoV-2 in studies using animal models?',
#   'In animal-based research on COVID-19, which drugs have been effective in targeting SARS-CoV or SARS-CoV-2?',
#   'What treatments have been tested and proven active against SARS-CoV or SARS-CoV-2 in experimental animal studies?',
#   'Which compounds or medications have exhibited antiviral effects against SARS-CoV or SARS-CoV-2 in preclinical trials involving animals?'],
#  '6': ['What are the different types of rapid diagnostic tests available for detecting Covid-19?',
#   'Which rapid testing methods have been developed for coronavirus detection?',
#   'What kinds of rapid Covid-19 tests are currently in use or have been created?',
#   'Can you list the various rapid testing technologies designed for SARS-CoV-2 identification?',
#   'What are the available rapid testing approaches for diagnosing coronavirus infections?'],
#  '7': ['What serological assays are available for detecting antibodies against coronavirus?',
#   'Are there antibody detection methods for coronavirus using serological testing?',
#   'Which serological tests are used to identify coronavirus-specific antibodies?',
#   'Can serological techniques detect immune responses to coronavirus through antibodies?',
#   'Are there diagnostic serological tools for measuring coronavirus antibody levels?'],
#  '8': ['How has limited access to testing contributed to the underreporting of the actual prevalence of Covid-19 infections?',
#   'In what ways has the shortage of Covid-19 testing resources resulted in an underestimation of true case numbers?',
#   'How does the lack of widespread testing impact the accurate reporting of Covid-19 incidence rates?',
#   'What role has insufficient testing capacity played in the underreporting of the true spread of coronavirus?',
#   'How has the unavailability of adequate testing influenced the misrepresentation of Covid-19 case counts in official data?'],
#  '9': ['What has been the impact of the coronavirus pandemic on Canada?',
#   'How has COVID-19 influenced public health and society in Canada?',
#   'What are the effects of SARS-CoV-2 on Canada’s population and economy?',
#   'In what ways has the COVID-19 outbreak shaped Canada’s healthcare and policies?',
#   'How has the spread of the novel coronavirus affected Canadian communities and systems?'],
#  '10': ['What is the effect of social distancing measures on reducing the transmission of coronavirus (COVID-19)?',
#   'How has the implementation of social distancing influenced the spread of COVID-19?',
#   'Does maintaining social distance contribute to controlling the spread of the coronavirus pandemic?',
#   'What role has social distancing played in mitigating the spread of SARS-CoV-2?',
#   'To what extent has social distancing been effective in slowing the progression of COVID-19 infections?'],
#  '11': ['What are the protocols for patient triage in hospitals during the coronavirus pandemic?',
#   'How do hospitals prioritize care for COVID-19 patients under resource constraints?',
#   'What guidelines exist for rationing medical resources for coronavirus-infected individuals?',
#   'How is patient triaging managed in healthcare settings for those diagnosed with COVID-19?',
#   'What are the clinical criteria for allocating treatment to coronavirus patients in overwhelmed hospitals?'],
#  '12': ['What are the recommended best practices for maintaining quarantine in hospitals and at home during a coronavirus outbreak?',
#   'How should quarantine protocols be implemented effectively in healthcare settings and residential environments for coronavirus containment?',
#   'What strategies are advised for ensuring proper quarantine measures in both medical facilities and domestic spaces during a coronavirus pandemic?',
#   'What are the guidelines for managing coronavirus quarantine in hospital settings and private homes to prevent transmission?',
#   'How can hospitals and households optimize quarantine procedures to control the spread of coronavirus?'],
#  '13': ['What are the mechanisms and pathways through which coronavirus is transmitted?',
#   'How is coronavirus spread, and what are its primary modes of transmission?',
#   'What are the routes and processes involved in the transmission of coronavirus?',
#   'How does the coronavirus propagate, and what are the key factors influencing its spread?',
#   'What are the different ways coronavirus can be transmitted between individuals?'],
#  '14': ['What scientific evidence exists regarding super spreader events in the context of COVID-19 and coronavirus transmission?',
#   'How do super spreaders contribute to the spread of COVID-19, and what research supports this phenomenon?',
#   'What studies or data highlight the role of coronavirus super spreaders in the transmission dynamics of COVID-19?',
#   'Are there documented cases or evidence in scientific literature about COVID-19 being amplified by super spreader individuals or events?',
#   'What is known from research about the impact of super spreaders on the epidemiology of the coronavirus pandemic?'],
#  '15': ['What is the survival time of the coronavirus on surfaces outside the human body?',
#   'How long does the coronavirus remain viable in external environments?',
#   'What is the lifespan of the coronavirus outside a host organism?',
#   'For how long can the coronavirus persist on inanimate objects or surfaces?',
#   'What is the duration of coronavirus stability outside biological systems?'],
#  '16': ['What is the duration of coronavirus stability on various surfaces?',
#   'How long can the coronavirus persist on different types of surfaces?',
#   'What is the survival time of the coronavirus on surfaces under different conditions?',
#   'For how long does the coronavirus remain viable on surfaces?',
#   'What is the lifespan of the coronavirus on surfaces in diverse environments?'],
#  '17': ['Are there any ongoing clinical trials related to coronavirus treatments or vaccines?',
#   'What clinical studies are currently being conducted for coronavirus research?',
#   'Are there active medical trials investigating therapies or interventions for the coronavirus?',
#   'Can you provide information on current clinical trials focused on COVID-19?',
#   'What are the latest clinical experiments or trials addressing coronavirus-related diseases?'],
#  '18': ['What types of masks are most effective at preventing the spread of Covid-19 infection?',
#   'Which face coverings provide the highest level of protection against coronavirus transmission?',
#   'What are the best respiratory masks to reduce the risk of contracting Covid-19?',
#   'How do different mask types compare in preventing SARS-CoV-2 infection?',
#   'What is the most effective personal protective equipment for minimizing Covid-19 exposure?'],
#  '19': ['Which types of alcohol-based hand sanitizers are effective against the coronavirus (SARS-CoV-2)?',
#   'What concentration of alcohol in hand sanitizers is required to inactivate Covid-19?',
#   'How do alcohol sanitizers work to eliminate the coronavirus, and which formulations are most effective?',
#   'What are the recommended hand sanitizer ingredients for killing the virus that causes Covid-19?',
#   'What is the efficacy of alcohol-based sanitizers in destroying SARS-CoV-2, and what formulations are ideal?'],
#  '20': ['Are patients using ACE inhibitors (Angiotensin-converting enzyme inhibitors) at a higher risk of contracting COVID-19?',
#   'Does the use of Angiotensin-converting enzyme inhibitors (ACE inhibitors) increase susceptibility to coronavirus infection?',
#   'Is there an elevated risk of COVID-19 in individuals taking ACE inhibitors for hypertension or other conditions?',
#   'How does the use of ACE inhibitors impact the likelihood of developing severe COVID-19 symptoms or infection?',
#   'Are patients prescribed Angiotensin-converting enzyme inhibitors more vulnerable to coronavirus-related complications?'],
#  '21': ['What are the overall mortality rates and population-specific death rates associated with coronavirus?',
#   'How does coronavirus impact mortality rates across different demographics and in general?',
#   'What is the fatality rate of coronavirus, both globally and within specific subpopulations?',
#   'Can you provide data on coronavirus mortality, including overall trends and rates in distinct groups?',
#   'What are the observed coronavirus death rates, both in the general population and among specific cohorts?'],
#  '22': ['What are the potential cardiac complications associated with COVID-19, and how does the coronavirus affect the heart?',
#   'Are patients with COVID-19 at risk of developing heart-related issues or cardiovascular impacts?',
#   'How does SARS-CoV-2 infection influence cardiac health, and what are the chances of heart complications?',
#   'Can COVID-19 lead to cardiovascular problems, and what is the likelihood of cardiac involvement in infected individuals?',
#   'What is the relationship between COVID-19 and heart function, and are cardiac complications a common outcome?'],
#  '23': ['What are the complications of COVID-19 in patients with pre-existing hypertension?',
#   'How does hypertension influence the severity or outcomes of coronavirus infections?',
#   'Are there specific COVID-19-related health issues linked to individuals with high blood pressure?',
#   'What is the relationship between hypertension and complications arising from SARS-CoV-2 infection?',
#   'How does having hypertension affect the risk of developing severe complications from COVID-19?'],
#  '24': ['What are the complications of COVID-19 in individuals with diabetes?',
#   'How does diabetes influence the severity or outcomes of coronavirus infections?',
#   'What types of health issues arise in diabetic patients infected with COVID-19?',
#   'Are there specific COVID-19-related complications linked to diabetes?',
#   'How does having diabetes affect the risk of complications from SARS-CoV-2?'],
#  '25': ['What are the key biomarkers associated with predicting severe outcomes in 2019-nCoV (coronavirus) infections?',
#   'Which biological markers are indicative of a severe clinical progression in COVID-19 cases?',
#   'What biomarkers have been identified as predictors of critical illness in SARS-CoV-2 infections?',
#   'Are there specific molecular or physiological indicators linked to severe disease in coronavirus (2019-nCoV) patients?',
#   'Which measurable biomarkers can forecast the likelihood of severe disease progression in COVID-19?'],
#  '26': ['What are the early clinical signs and symptoms associated with coronavirus infection?',
#   'Can you describe the initial manifestations of Covid-19 in patients?',
#   'What are the primary early-stage symptoms observed in individuals with coronavirus disease?',
#   'Which symptoms typically appear first in cases of Covid-19 infection?',
#   'What are the common early indicators of SARS-CoV-2 infection?'],
#  '27': ['What scientific information is available about individuals infected with coronavirus who show no symptoms?',
#   'What is currently understood about asymptomatic cases of Covid-19 infection?',
#   'What research has been conducted on people who are asymptomatic carriers of the coronavirus?',
#   'What do studies reveal about the characteristics of asymptomatic Covid-19 patients?',
#   'What is known in the scientific literature about the transmission and effects of coronavirus in asymptomatic individuals?'],
#  '28': ['What scientific evidence supports the use of hydroxychloroquine as a treatment for Covid-19 or coronavirus infections?',
#   'Are there any studies or clinical trials that demonstrate the effectiveness of hydroxychloroquine in managing Covid-19 symptoms?',
#   'What is the current research consensus on the therapeutic role of hydroxychloroquine in combating SARS-CoV-2?',
#   'Has hydroxychloroquine been proven to be beneficial in treating coronavirus disease, and what evidence exists to support this?',
#   'What data or findings are available regarding the efficacy of hydroxychloroquine in treating patients with Covid-19?'],
#  '29': ['What SARS-CoV-2 and human protein interactions suggest potential drug targets for coronavirus treatment, and are there any existing approved drugs that could be repurposed based on these findings?',
#   'Which interactions between SARS-CoV-2 proteins and human proteins highlight opportunities for drug repurposing, and are there currently approved drugs that align with these targets?',
#   'Are there any approved drugs that can be repurposed for COVID-19 treatment by targeting specific SARS-CoV-2-human protein interactions identified as potential drug targets?',
#   'Based on the interactions between SARS-CoV-2 proteins and human proteins, what are the most promising drug targets, and can any existing drugs be repurposed to exploit these targets?',
#   'How do SARS-CoV-2-human protein interactions inform drug repurposing efforts, and are there any approved drugs that could be used to target these interactions for coronavirus therapy?'],
#  '30': ['Is remdesivir a scientifically proven treatment for coronavirus or COVID-19?',
#   'What is the efficacy of remdesivir in treating patients with COVID-19 or SARS-CoV-2 infection?',
#   'Can remdesivir be considered an effective antiviral therapy for coronavirus disease?',
#   'How effective is remdesivir in managing or treating COVID-19 symptoms caused by the coronavirus?',
#   'What does current research say about the use of remdesivir as a treatment for SARS-CoV-2?'],
#  '31': ['What are the key differences between COVID-19 and influenza in terms of symptoms and transmission?',
#   'How do coronaviruses and the flu virus compare in their biological structure and impact on public health?',
#   'In what ways do the clinical features of coronavirus infections differ from those of the flu?',
#   'What distinguishes the coronavirus from the influenza virus in terms of epidemiology and disease progression?',
#   'How do SARS-CoV-2 and influenza viruses vary in their mechanisms of infection and global spread?'],
#  '32': ['What are the known variants or subtypes of SARS-CoV-2, the virus responsible for COVID-19?',
#   'Are there any genetic sublineages or classifications of the coronavirus SARS-CoV-2?',
#   'Has SARS-CoV-2 been categorized into distinct strains or subtypes, and what are their characteristics?',
#   'Does the novel coronavirus SARS-CoV-2 exhibit any genomic diversity in the form of subtypes or variants?',
#   'What subgroups, mutations, or evolutionary branches of SARS-CoV-2 have been identified in scientific research?'],
#  '33': ['What are the current vaccine candidates under development for the coronavirus (Covid-19)?',
#   'Which Covid-19 vaccines are undergoing clinical trials or testing?',
#   'What experimental vaccines are being studied to combat the SARS-CoV-2 virus?',
#   'Can you provide information on the vaccine candidates being evaluated for coronavirus disease?',
#   'What are the leading vaccine development efforts targeting Covid-19?'],
#  '34': ['What are the long-term health effects experienced by individuals who have recovered from coronavirus (COVID-19)?',
#   'What chronic conditions or complications can arise in patients after recovering from COVID-19 infection?',
#   'Are there any persistent symptoms or lasting impacts on health following recovery from the coronavirus disease?',
#   'What post-recovery medical issues or long-term sequelae are associated with COVID-19 survivors?',
#   'How does recovery from COVID-19 affect long-term physical or mental health outcomes?'],
#  '35': ['What are the latest publicly available datasets related to the coronavirus pandemic?',
#   'Are there any new open-access datasets focused on COVID-19 research?',
#   'What recent public data collections have been released for studying SARS-CoV-2?',
#   'Where can I find updated COVID-19 datasets for scientific analysis?',
#   'Have any new shared datasets on the novel coronavirus been published recently?'],
#  '36': ['What is the molecular structure of the SARS-CoV-2 spike protein?',
#   'Can you describe the 3D conformation of the spike protein in SARS-CoV-2?',
#   'What are the structural characteristics of the SARS-CoV-2 spike glycoprotein?',
#   'How is the SARS-CoV-2 spike protein organized at the atomic level?',
#   "What are the key features of the SARS-CoV-2 spike protein's tertiary structure?"],
#  '37': ['What are the findings from the phylogenetic analysis of the SARS-CoV-2 genome?',
#   'How does the phylogenetic study of SARS-CoV-2 genomic sequences contribute to understanding its evolution?',
#   'What insights have been gained from analyzing the phylogenetic relationships of SARS-CoV-2?',
#   'What does the genomic phylogenetic analysis reveal about the evolutionary history of SARS-CoV-2?',
#   'How has phylogenetic research on the SARS-CoV-2 genome informed our understanding of its genetic diversity?'],
#  '38': ['What are the underlying mechanisms of the inflammatory response and disease progression in COVID-19 patients?',
#   'How does COVID-19 trigger inflammation, and what are the key pathways involved in its pathogenesis?',
#   'What is the role of the immune system in the inflammatory response observed in COVID-19 infections?',
#   'Can you explain the molecular and cellular mechanisms driving inflammation and pathogenesis in SARS-CoV-2 cases?',
#   'What are the biological processes and immune responses associated with inflammation in COVID-19 pathology?'],
#  '39': ['What are the underlying mechanisms of cytokine storm syndrome in COVID-19 patients?',
#   'How does COVID-19 trigger a cytokine storm, and what are the biological pathways involved?',
#   'What is the pathophysiology of cytokine storm syndrome in the context of SARS-CoV-2 infection?',
#   'Can you explain the molecular and immunological mechanisms driving cytokine storm in COVID-19?',
#   'What role do immune system dysregulation and cytokine release play in severe COVID-19 cases?'],
#  '40': ['What are the documented genetic mutations in the SARS-CoV-2 virus, and what is their frequency of occurrence?',
#   'How frequently do mutations arise in the genome of SARS-CoV-2, and what specific changes have been identified?',
#   'Can you provide an overview of the observed variations in the SARS-CoV-2 genetic sequence and their mutation rates?',
#   'What are the known alterations in the SARS-CoV-2 RNA genome, and how commonly do these mutations take place?',
#   'Which mutations have been detected in the SARS-CoV-2 genome, and what is the rate at which they are observed?'],
#  '41': ['How has COVID-19 disproportionately affected African-American communities compared to other populations in the United States?',
#   'What are the unique health and socioeconomic impacts of COVID-19 on African-Americans in the U.S.?',
#   'In what ways does the impact of COVID-19 on African-Americans differ from its effects on other demographic groups in the U.S.?',
#   'What disparities exist in the outcomes of COVID-19 for African-Americans relative to the broader U.S. population?',
#   'How do the effects of COVID-19 on African-Americans compare to those experienced by other racial and ethnic groups in the United States?'],
#  '42': ['What is the role of Vitamin D in the prevention and treatment of COVID-19?',
#   'Can Vitamin D supplementation influence outcomes in COVID-19 patients?',
#   'Is there a connection between Vitamin D levels and susceptibility to COVID-19?',
#   'How does Vitamin D affect the immune response against COVID-19?',
#   'Are there any studies linking Vitamin D deficiency to COVID-19 severity or recovery?'],
#  '43': ['What has been the effect of the COVID-19 pandemic on societal violence and rates of violent crime?',
#   'How did the COVID-19 pandemic influence patterns of violence and criminal behavior in communities?',
#   'In what ways has violence, including violent crime, changed during the COVID-19 pandemic?',
#   'What are the societal impacts of the COVID-19 pandemic on violence and aggression, particularly in terms of crime rates?',
#   'How has the prevalence of violent crimes and other forms of violence shifted during the COVID-19 pandemic?'],
#  '44': ['What is the effectiveness of face masks in reducing the transmission of COVID-19?',
#   'How do masks influence the spread of the coronavirus in community settings?',
#   'To what extent do facial coverings mitigate the transmission of SARS-CoV-2?',
#   'What role do masks play in controlling the spread of COVID-19 infections?',
#   'How significant is the use of masks in preventing the dissemination of the coronavirus?'],
#  '45': ['What are the psychological effects of the coronavirus pandemic on mental health?',
#   'How has the COVID-19 crisis influenced mental well-being and emotional health?',
#   'What is the impact of the SARS-CoV-2 pandemic on mental health outcomes?',
#   'In what ways has the coronavirus outbreak affected mental health and psychological resilience?',
#   'How has the global COVID-19 pandemic shaped trends in mental health and emotional disorders?'],
#  '46': ['What scientific evidence supports the use of dexamethasone in treating COVID-19 patients?',
#   'How effective is dexamethasone as a therapeutic option for coronavirus infection?',
#   'Are there studies or clinical trials demonstrating the efficacy of dexamethasone for COVID-19 treatment?',
#   'What research findings exist regarding the role of dexamethasone in managing COVID-19 symptoms?',
#   'Can dexamethasone be considered a proven treatment for SARS-CoV-2, and what evidence backs this claim?'],
#  '47': ['What are the health effects and clinical outcomes of COVID-19 infection in pediatric populations?',
#   'How does COVID-19 impact the health and recovery of children who become infected?',
#   'What are the short-term and long-term health consequences of COVID-19 in children?',
#   'What is known about the medical outcomes and disease progression of COVID-19 in children?',
#   'How does SARS-CoV-2 infection affect the physical health and well-being of children?'],
#  '48': ['What are the advantages and disadvantages of reopening schools during the COVID-19 pandemic?',
#   'How does reopening schools impact public health and education outcomes amid the coronavirus crisis?',
#   'What are the potential risks and benefits associated with resuming in-person schooling during the COVID-19 outbreak?',
#   'In the context of the COVID-19 pandemic, what are the implications of reopening schools for students, teachers, and communities?',
#   'What are the health, social, and educational trade-offs of reopening schools during the coronavirus pandemic?'],
#  '49': ['What is the extent of immune response, including antibody production and T-cell activity, in individuals recovering from COVID-19, and does it provide protection against re-infection?',
#   'Do individuals recovering from COVID-19 develop adequate post-infection immunity, such as robust antibody levels and T-cell responses, to prevent subsequent infections?',
#   'How effective is the immune response, including humoral and cellular immunity, in individuals who have recovered from COVID-19 in preventing re-infection?',
#   'After recovering from COVID-19, do individuals exhibit sufficient adaptive immunity, including both antibody-mediated and T-cell-mediated defenses, to avoid re-infection?',
#   'To what degree do recovered COVID-19 patients generate lasting immunity, encompassing antibody responses and T-cell functionality, to protect against future infections?'],
#  '50': ['What scientific information is available about mRNA vaccines developed for SARS-CoV-2 or COVID-19?',
#   'What are the current findings and research on mRNA-based vaccines targeting the coronavirus responsible for COVID-19?',
#   'What is the state of knowledge regarding mRNA vaccine technology for combating the SARS-CoV-2 virus?',
#   'How do mRNA vaccines function in the context of SARS-CoV-2, and what has been discovered so far?',
#   'What is the scientific understanding of mRNA vaccines designed to protect against the novel coronavirus?']}

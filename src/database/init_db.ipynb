# %%
import model
from dotenv import dotenv_values
from database_setup import setup_engine_session

# %%
db_vals = dotenv_values("/workspace/.env")
session = setup_engine_session(db_vals['USER'], db_vals['PASSWORD'], db_vals['ADDRESS'], db_vals['PORT'], db_vals['DB'])
# Out:
# 2024-12-02 12:54:54,708 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2024-12-02 12:54:54,710 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-12-02 12:54:54,748 INFO sqlalchemy.engine.Engine select current_schema()
# 2024-12-02 12:54:54,750 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-12-02 12:54:54,785 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2024-12-02 12:54:54,785 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-12-02 12:54:54,818 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-02 12:54:54,822 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# ...
